# %% [markdown]
# piloit programm

# %%
a=1000
b=10000

# %%
for altitude in range(a,b):
  altitude=int(input('enter altitude'))
  if altitude==1000:
    print('safe to land')
  elif altitude>1000 & altitude<5000:
    print('bring down to 1000')
  else:
    print('turn around')
# Out:
# enter altitude1000
# safe to land
# enter altitude4500
# bring down to 1000
# enter altitude6500
# bring down to 1000
